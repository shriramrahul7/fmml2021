# %% [markdown]
# <a href="https://colab.research.google.com/github/shriramrahul7/fmml2021/blob/main/LABS/Module8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-07-17 07:10:56--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   287MB/s    in 0.2s
#
# 2022-07-17 07:10:59 (287 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 14382  cs/9912003v1  A noun phrase can indirectly refer to an entit...    cs
# 39647  1611.05963v4  The t-SVD based Tensor Robust Principal Compon...    cs
# 22643  1703.05841v1  This work addresses various open questions in ...  stat
# 36222  1505.04981v2  We recently performed cognitive experiments on...    cs
# 18263   0706.1290v1  Representing and reasoning about qualitative t...    cs
# ...             ...                                                ...   ...
# 20933  1705.06342v1  In this work, we present a methodology that en...    cs
# 11792  1701.05512v2  We introduce Fisher consistency in the sense o...  stat
# 2596   1608.05921v2  Knowledge graph construction consists of two t...  stat
# 529    1511.02506v1  In this paper we propose the Structured Deep N...    cs
# 38667   1304.7713v1  Radar (SAR) images often exhibit profound appe...    cs
#
#                                                    title  year  \
# 14382  Resolution of Indirect Anaphora in Japanese Se...  1999
# 39647  Reweighted Low-Rank Tensor Decomposition based...  2016
# 22643  Adaptivity to Noise Parameters in Nonparametri...  2017
# 36222  A New Fundamental Evidence of Non-Classical St...  2015
# 18263       Temporal Reasoning without Transitive Tables  2007
# ...                                                  ...   ...
# 20933  Identification and Off-Policy Learning of Mult...  2017
# 11792     Fisher consistency for prior probability shift  2017
# 2596   Probabilistic Knowledge Graph Construction: Co...  2016
# 529    Towards Structured Deep Neural Network for Aut...  2015
# 38667  Markovian models for one dimensional structure...  2013
#
#                                                 keywords
# 14382  [indirectly, mentioned, indicates, associated,...
# 39647  [principal, component, decomposes, corrupted, ...
# 22643  [addresses, questions, nonparametric, classifi...
# 36222  [performed, cognitive, experiments, conjunctio...
# 18263  [representing, reasoning, qualitative, informa...
# ...                                                  ...
# 20933  [methodology, efficient, exploratory, autonomo...
# 11792  [introduce, consistency, unbiasedness, desirab...
# 2596   [knowledge, construction, extracting, informat...
# 529    [structured, structured, framework, structured...
# 38667  [appearance, variations, including, illuminati...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 14382    [indirectly, mentioned, indicates, associated,...
# 39647    [principal, component, decomposes, corrupted, ...
# 22643    [addresses, questions, nonparametric, classifi...
# 36222    [performed, cognitive, experiments, conjunctio...
# 18263    [representing, reasoning, qualitative, informa...
#                                ...
# 24354    [intensive, interests, detection, segmentation...
# 22995    [formulate, supervised, continuous, continuous...
# 35127    [introduce, uncertainty, plausibility, general...
# 12150    [enhancement, objective, parameters, inconsist...
# 1064     [omnipresence, architectures, convolutional, s...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8791 words.
# Out of those 4638 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e848e3a1-2813-40ba-a95e-0443946e044b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e848e3a1-2813-40ba-a95e-0443946e044b")) {                    Plotly.newPlot(                        "e848e3a1-2813-40ba-a95e-0443946e044b",                        [{"x":["therefore","relationships","translation","coherence","presently","dictionary","resolution","indicates","important","processing","sentences","associated","reference","mentioned","precision","understanding","estimated","respectively","construct","information","estimating","indirectly","knowledge","established","reweighted","outperforms","denoising","corrupted","experimental","considerably","simultaneously","efficient","minimizing","iterative","decomposition","decomposes","significantly","performance","recovered","algorithm","deteriorates","component","counterparts","principal","effectiveness","applications","statistical","transitions","conjectured","interaction","situations","establish","confidence","parameters","classification","resulting","contributions","smoothness","furthermore","nonparametric","adaptivity","addresses","previously","distributional","conditions","requirements","questions","algorithmic","interesting","theoretic","violation","performed","structure","conceptual","combinations","combination","ourselves","explained","experiments","identified","emergence","negations","probability","investigating","faithfully","deviations","regularity","processes","successfully","cognition","confirmed","developed","reasoning","mechanism","framework","cognitive","determining","classical","conjunctions","generally","fundamental","vagueness","systematic","similarly","inference","essential","indefinite","represent","incomplete","artificial","alternative","frameworks","qualitative","representing","consistent","intelligence","relations","languages","transitive","following","conclusions","extracted","validated","representative","classifier","consistently","approximates","extraction","demonstrate","automatic","effective","answering","quantitatively","underlying","importance","sentiment","representation","identifying","practical","contribution","advancements","filtering","optimization","instances","simulation","impractical","analytical","interested","combinatorial","approaches","collaborative","reconstruct","recommendations","generative","providing","technologies","recommender","algorithms","automation","detection","linguistic","popularity","criterion","discussion","detecting","followers","influence","potential","increasing","advertisements","automated","perceived","community","exclusively","typically","similarity","equivalent","prediction","empirical","competitive","similarities","reconstructing","correlation","typological","properties","resources","unsupervised","psychologists","structural","procedure","traditional","separately","unlabeled","computation","dimensional","practitioner","selection","particular","probabilistic","themselves"],"y":[142,73,98,20,3,51,126,25,369,289,68,121,47,19,84,166,75,85,108,734,69,6,366,43,5,264,38,20,371,35,102,406,53,77,62,11,269,875,8,795,2,98,14,33,205,425,157,14,4,95,51,53,38,240,525,165,49,13,165,12,1,63,107,25,136,42,66,39,69,41,4,127,354,22,34,134,3,17,607,34,18,3,168,13,6,6,7,108,83,13,9,206,126,93,561,55,31,87,7,75,87,5,30,17,188,55,2,111,46,132,86,29,51,77,99,97,102,94,5,90,26,126,34,39,169,39,8,142,548,173,267,41,25,112,94,50,386,85,147,64,4,52,291,109,80,8,15,28,40,427,35,34,18,106,86,36,20,580,15,312,69,19,44,34,69,3,56,155,93,4,80,8,79,9,111,151,48,233,145,115,30,14,61,2,207,60,147,3,69,116,173,35,58,162,175,2,160,285,160,18],"type":"bar"},{"x":["therefore","relationships","translation","coherence","presently","dictionary","resolution","indicates","imp ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4638,), (4638, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Computational</span> <span style=''>Model</span> <span style=''>for</span> <span style=''>Situated</span> <span style=''>Task</span> <span style=''>Learning</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.6231884057971016);'>Interactive</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Instruction</span> <br/><br/><span style=''>Learning</span> <span style=''>novel</span> <span style=''>tasks</span> <span style=''>is</span> <span style=''>a</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.6176470588235294);'>cognitive</span> <span style=''>activity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requiring</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>to</span> <span style=''>acquire</span> <span style=''>diverse</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>declarative</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>procedural</span> <span style='background-color:rgba(0, 255, 0, 0.4131274131274132);'>knowledge</span> <span style=''>Prior</span> <span style=''>ACT</span> <span style=''>R</span> <span style=''>models</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>acquiring</span> <span style=''>task</span> <span style='background-color:rgba(0, 255, 0, 0.4131274131274132);'>knowledge</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>instruction</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>procedural</span> <span style='background-color:rgba(0, 255, 0, 0.4131274131274132);'>knowledge</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>declarative</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>instructions</span> <span style=''>encoded</span> <span style=''>in</span> <span style=''>semantic</span> <span style=''>memory</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>identify</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirements</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3086419753086419);'>designing</span> <span style=''>compu</span> <span style=''>tational</span> <span style=''>models</span> <span style=''>that</span> <span style=''>learn</span> <span style=''>task</span> <span style='background-color:rgba(0, 255, 0, 0.4131274131274132);'>knowledge</span> <span style=''>from</span> <span style=''>situated</span> <span style=''>task</span> <span style=''>oriented</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interactions</span> <span style=''>with</span> <span style=''>an</span> <span style=''>expert</span> <span style=''>and</span> <span style=''>then</span> <span style=''>describe</span> <span style=''>and</span> <span style=''>evaluate</span> <span style=''>a</span> <span style=''>model</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>from</span> <span style=''>situated</span> <span style='background-color:rgba(0, 255, 0, 0.6231884057971016);'>interactive</span> <span style=''>instruc</span> <span style=''>tion</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.343065693430657);'>implemented</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Soar</span> <span style='background-color:rgba(0, 255, 0, 0.6176470588235294);'>cognitive</span> <span style='background-color:rgba(0, 255, 0, 0.5657894736842104);'>architecture</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>experts</span> <span style=''>modeling</span> <span style=''>using</span> <span style=''>the</span> <span style=''>t</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <br/><br/><span style=''>Mixture</span> <span style=''>of</span> <span style=''>Experts</span> <span style=''>(MoE)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>modeling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneity</span> <span style=''>in</span> <span style=''>data</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>For</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style=''>cluster</span> <span style=''>analyses</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>data</span> <span style=''>MoE</span> <span style=''>usually</span> <span style=''>use</span> <span style=''>normal</span> <span style=''>experts</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>However</span> <span style=''>for</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>containing</span> <span style=''>a</span> <span style=''>group</span> <span style=''>or</span> <span style=''>groups</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>with</span> <span style=''>heavy</span> <span style=''>tails</span> <span style=''>or</span> <span style=''>atypical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>normal</span> <span style=''>experts</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unsuitable</span> <span style=''>and</span> <span style=''>can</span> <span style=''>unduly</span> <span style=''>affect</span> <span style=''>the</span> <span style=''>fit</span> <span style=''>of</span> <span style=''>the</span> <span style=''>MoE</span> <span style=''>model</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>robust</span> <span style=''>MoE</span> <span style=''>modeling</span> <span style=''>using</span> <span style=''>the</span> <span style=''>t</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>t</span> <span style=''>MoE</span> <span style=''>(TMoE)</span> <span style=''>deals</span> <span style=''>with</span> <span style=''>these</span> <span style=''>issues</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regarding</span> <span style=''>heavy</span> <span style=''>tailed</span> <span style=''>and</span> <span style=''>noisy</span> <span style=''>data</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dedicated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximization</span> <span style=''>(EM)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>al ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(255, 0, 0, 0.6346153846153848);'>Estimators</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dimension</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reductions</span> <span style=''>Using</span> <span style=''>Stable</span> <span style=''>Random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Projections</span> <br/><br/><span style=''>The</span> <span style=''>method</span> <span style=''>of</span> <span style=''>stable</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projections</span> <span style=''>is</span> <span style=''>a</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>the</span> <span style=''>l</span> <span style=''>alpha</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distances</span> <span style=''>using</span> <span style=''>low</span> <span style=''>memory</span> <span style=''>where</span> <span style=''>0alpha</span> <span style=''>leq</span> <span style=''>2</span> <span style=''>is</span> <span style=''>a</span> <span style=''>tuning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>The</span> <span style=''>method</span> <span style=''>boils</span> <span style=''>down</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>task</span> <span style=''>and</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.6346153846153848);'>estimators</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>geometric</span> <span style=''>mean</span> <span style=''>the</span> <span style=''>harmonic</span> <span style=''>mean</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fractional</span> <span style=''>power</span> <span style=''>etc</span> <span style=''>This</span> <span style=''>study</span> <span style=''>proposes</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>quantile</span> <span style='background-color:rgba(255, 0, 0, 0.6309523809523809);'>estimator</span> <span style=''>whose</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.47540983606557385);'>operation</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.37254901960784326);'>considerably</span> <span style=''>less</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>than</span> <span style=''>taking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fractional</span> <span style=''>power</span> <span style=''>the</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.47540983606557385);'>operation</span> <span style=''>in</span> <span style=''>previous</span> <span style='background-color:rgba(255, 0, 0, 0.6346153846153848);'>estimators</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>report</span> <span style=''>that</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>quantile</span> <span style='background-color:rgba(255, 0, 0, 0.6309523809523809);'>estima ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Discriminative</span> <span style=''>k</span> <span style=''>shot</span> <span style=''>learning</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>models</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>k</span> <span style=''>shot</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalise</span> <span style=''>from</span> <span style=''>an</span> <span style=''>initial</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>task</span> <span style=''>to</span> <span style=''>a</span> <span style=''>separate</span> <span style=''>task</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprising</span> <span style=''>new</span> <span style=''>classes</span> <span style=''>and</span> <span style=''>small</span> <span style=''>numbers</span> <span style=''>of</span> <span style=''>examples</span> <span style=''>The</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>not</span> <span style=''>only</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leverages</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>learned</span> <span style=''>by</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>from</span> <span style=''>the</span> <span style=''>initial</span> <span style=''>task</span> <span style=''>(representational</span> <span style=''>transfer)</span> <span style=''>but</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style=''>classes</span> <span style=''>(concept</span> <span style=''>transfer)</span> <span style=''>The</span> <span style=''>concept</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encapsulated</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>for</span> <span style=''>the</span> <span style=''>final</span> <span style=''>layer</span> <span style=''>weights</span> <span style=''>of</span> <span style=''>the</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>which</span> <span style=''>acts</span> <span style=''>as</span> <span style=''>a</span> <span style=''>prior</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>k</span> <span style=''>shot</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>even</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>achieves</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>on</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>k</span> <span style=''>shot</span> <span style=''>l ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.0851520572450805)
# 	experimental (0.13273703041144902)
# 	representation (0.13810375670840788)
# 	segmentation (0.0704830053667263)
# 	knowledge (0.13094812164579606)
# 	detection (0.11162790697674418)
# 	different (0.2608228980322004)
# 	information (0.2626118067978533)
# 	convolutional (0.13166368515205726)
# 	recognition (0.13917710196779964)
#
# Some Statistics words are:
# 	stochastic (0.13665835411471322)
# 	algorithm (0.38054862842892767)
# 	variables (0.14114713216957606)
# 	estimation (0.1685785536159601)
# 	theoretical (0.15062344139650874)
# 	statistical (0.15660847880299253)
# 	distribution (0.18304239401496258)
# 	dimensional (0.18154613466334166)
# 	regression (0.1855361596009975)
# 	inference (0.20947630922693267)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="abeab19e-f01c-4085-9c22-881a743aa787" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abeab19e-f01c-4085-9c22-881a743aa787")) {                    Plotly.newPlot(                        "abeab19e-f01c-4085-9c22-881a743aa787",                        [{"x":["therefore","relationships","translation","coherence","presently","dictionary","resolution","indicates","important","processing","sentences","associated","reference","mentioned","precision","understanding","estimated","respectively","construct","information","estimating","indirectly","knowledge","established","reweighted","outperforms","denoising","corrupted","experimental","considerably","simultaneously","efficient","minimizing","iterative","decomposition","decomposes","significantly","performance","recovered","algorithm","deteriorates","component","counterparts","principal","effectiveness","applications","statistical","transitions","conjectured","interaction","situations","establish","confidence","parameters","classification","resulting","contributions","smoothness","furthermore","nonparametric","adaptivity","addresses","previously","distributional","conditions","requirements","questions","algorithmic","interesting","theoretic","violation","performed","structure","conceptual","combinations","combination","ourselves","explained","experiments","identified","emergence","negations","probability","investigating","faithfully","deviations","regularity","processes","successfully","cognition","confirmed","developed","reasoning","mechanism","framework","cognitive","determining","classical","conjunctions","generally","fundamental","vagueness","systematic","similarly","inference","essential","indefinite","represent","incomplete","artificial","alternative","frameworks","qualitative","representing","consistent","intelligence","relations","languages","transitive","following","conclusions","extracted","validated","representative","classifier","consistently","approximates","extraction","demonstrate","automatic","effective","answering","quantitatively","underlying","importance","sentiment","representation","identifying","practical","contribution","advancements","filtering","optimization","instances","simulation","impractical","analytical","interested","combinatorial","approaches","collaborative","reconstruct","recommendations","generative","providing","technologies","recommender","algorithms","automation","detection","linguistic","popularity","criterion","discussion","detecting","followers","influence","potential","increasing","advertisements","automated","perceived","community","exclusively","typically","similarity","equivalent","prediction","empirical","competitive","similarities","reconstructing","correlation","typological","properties","resources","unsupervised","psychologists","structural","procedure","traditional","separately","unlabeled","computation","dimensional","practitioner","selection","particular","probabilistic","themselves","selecting","maximized","microarray","drawbacks","likelihood","variables","interpretation","difficult","variational","illustrated","components","synthetic","expectation","relaxation","interpreted","presented","maximization","polyhedral","parameterized","distances","promising","functions","formulate","descriptors","minimization","histograms","available","presentation","difference","carefully","application","parameter","limitation","transportation","practitioners","regularizer","accelerating","performing","initialization","exceeding","architecture","notoriously","complicated","validation","distribution","phenomenon","normalized","normalization","normalizing","saturating","eliminating","significant","nonlinearities","published","requiring","covariate","proposing","pho ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	interestingness
# 	framelets
# 	covariates
# 	degeneration
# 	neuroimage
# 	nonparanormal
# 	semiparametric
# 	schizophrenia
# 	accommodates
# 	exchangeability
# 	prohibits
# 	kronecker
# 	integrable
# 	bernsteins
# 	genuinely
# 	abnormally
# 	chemometrics
# 	psychiatric
# 	rademacher
# 	similitude
# Some words which never appear in Statistics papers:
# 	presently
# 	negations
# 	vagueness
# 	advertisements
# 	typological
# 	psychologists
# 	saturating
# 	photography
# 	dominance
# 	offspring
# 	contradictory
# 	realworld
# 	collaborations
# 	underwater
# 	progressive
# 	associativity
# 	transported
# 	pharmaceutical
# 	contracts
# 	blockchain

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0686142138210385e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7583333333333333
